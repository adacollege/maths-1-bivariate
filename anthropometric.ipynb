# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("Anthropometric data.csv")
data.head(5)
# Out:
#    Weight_N  Height_mm  Head_Circumference_mm  Shoulder_Breadth_mm  \
# 0       119        855                    479                  224
# 1       142        879                    497                  276
# 2       152        909                    481                  239
# 3       129        872                    504                  239
# 4       118        874                    461                  235
#
#    Hand_Length_mm  Hand_Breadth_mm  Chest_Circumference_mm  \
# 0              93               45                     473
# 1              96               48                     548
# 2             104               52                     523
# 3             102               44                     489
# 4             103               45                     470
#
#    Waist_Circumference_mm  Foot_Length_mm  Foot_Breadth_mm Gender  Age_months
# 0                     457             129               58      M          24
# ...

# %%
data.plot.scatter(x="Height_mm",y="Weight_N",figsize=(8,5));

# %%
data["Age_y"] = data.Age_months//12

# %%
data.tail(10)
# Out:
#       Weight_N  Height_mm  Head_Circumference_mm  Shoulder_Breadth_mm  \
# 3731       555       1673                    544                  393
# 3732       507       1588                    530                  384
# 3733       540       1661                    548                  398
# 3734       466       1543                    536                  388
# 3735       497       1577                    531                  402
# 3736       596       1663                    534                  410
# 3737       450       1586                    546                  387
# 3738       519       1572                    557                  406
# 3739       686       1704                    548                  422
# 3740       526       1675                    536                  376
#
#       Hand_Length_mm  Hand_Breadth_mm  Chest_Circumference_mm  \
# 3731             171               75                     830
# 3732             161               76                     813
# ...
