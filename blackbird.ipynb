# %%
import pandas as pd
# %matplotlib inline

# %%
blackbird_data = pd.read_csv("blackbirds.csv")

# %% [markdown]
# What if I only want to look at adult, male blackbirds..?

# %%
blackbird_data[(blackbird_data.Sex == "M")&(blackbird_data.Age=="A")].dropna()
# Out:
#      Age Sex   Wing  Weight  Year
# 0      A   M  133.0    95.0  2006
# 1      A   M  134.0   106.0  2012
# 2      A   M  135.0   125.0  1994
# 3      A   M  135.0   113.0  1994
# 4      A   M  135.0   111.0  1994
# 5      A   M  134.0   105.0  1994
# 20     A   M  132.0   107.0  2005
# 38     A   M  135.0   131.0  2004
# 39     A   M  135.0   121.0  2005
# 40     A   M  136.0   112.0  2005
# 41     A   M  136.0   106.0  2005
# 42     A   M  136.0   101.0  2005
# 43     A   M  137.0    98.0  2005
# 45     A   M  135.0    99.0  2005
# 46     A   M  135.0   134.0  2005
# 47     A   M  135.0   127.0  2005
# 48     A   M  136.0   128.0  2005
# 49     A   M  135.0   122.0  2005
# 50     A   M  136.0   132.0  2005
# 51     A   M  135.0   120.0  2006
# 52     A   M  135.0   112.0  2006
# 53     A   M  135.0    99.0  2006
# 54     A   M  135.0   102.0  2006
# 55     A   M  135.0   100.0  2006
# 56     A   M  135.0    98.0  2006
# 57     A   M  135.0    99.0  2006
# ...

# %%
blackbird_data.boxplot(column="Weight",by="Year")

# %%
blackbird_data.boxplot(column="Weight",by="Age")

# %%
blackbird_data.boxplot(by="Sex",column="Weight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fbe52167516b> in <module>()
# ----> 1 blackbird_data.boxplot(by="Sex",column="Weight")
#
# NameError: name 'blackbird_data' is not defined

# %%
blackbird_data.Weight.dropna()
# Out:
# 0        95.0
# 1       106.0
# 2       125.0
# 3       113.0
# 4       111.0
# 5       105.0
# 6       111.0
# 7       103.0
# 8       102.0
# 9       104.0
# 10       97.0
# 11      102.0
# 12      126.0
# 13      121.0
# 14       88.0
# 15       90.0
# 16      101.0
# 17      100.0
# 18       98.0
# 19       97.0
# 20      107.0
# 21       94.0
# 22      104.0
# 23       99.0
# 24      102.0
# 25      106.0
# 26      106.0
# 27       96.0
# 28       96.0
# 29       88.0
#         ...
# 4093    101.0
# 4094     93.0
# 4095    113.0
# 4096    115.0
# 4097    108.0
# 4098    109.0
# 4099    108.0
# 4100    104.0
# 4101    105.0
# 4102     96.0
# 4103     94.0
# 4104     90.0
# 4105    107.0
# 4106     99.0
# 4107    100.0
# 4108    104.0
# 4109    101.0
# 4110    100.0
# 4111    104.0
# 4112     96.0
# 4113    110.0
# 4114    103.0
# 4115     96.0
# 4116     95.0
# 4117     90.0
# 4118     86.0
# 4119     82.0
# 4120     79.0
# 4121     80.0
# 4122    102.0
# ...

# %%
len(blackbird_data[blackbird_data.Sex=="M"])/len(blackbird_data)
# Out:
# 0.5743390734901771

# %%
blackbird_data.plot.scatter(x="Wing",y="Weight")

# %%
blackbird_data.corr()
# Out:
#             Wing    Weight      Year
# Wing    1.000000  0.412906  0.100095
# Weight  0.412906  1.000000  0.062349
# Year    0.100095  0.062349  1.000000
